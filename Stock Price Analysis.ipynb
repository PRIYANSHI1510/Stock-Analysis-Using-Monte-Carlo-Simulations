# %% [markdown]
# # Stock Price Analysis

# %% [markdown]
# ## Section 1: Data Selection and Data Source
# **In one or two paragraphs, describe the time series dataset you have selected, including its source and how the data are published. Why did you decide on this dataset in particular?
# Discuss some potential explanations of the data-geneating process based on what you know. What drives variation in the variable? Why or why not do you think this might be an easy/difficult variable to forecast?**
#
# I have taken data of stock market from **yahoo finance** of four technology giants for the past two years.The data has 6 columns 'High','Low','Close','Adj Close'and 'Open' cost for the stocks and their volume.The dataset is continous time series data and also the stock market gets affected by various unpredicted factors and is affected by seasonality so it'll be challenging to predict the future stock behaviour with several forecasting methods.
#
# **Data generating process**  generates the data one is interested in. Usually, are unaware of the the real data generating model. but aware of the consequences which can be used to choose distributions or models that represent and generate data through the mathematical functions like normal distribution, Bernoulli distribution, Poisson distribution, etc.
#
# **Variation in Variable** is due to variations in recording observations caused due to several reasons including bias, errors, and lack of skill  or external factors like change in time or surrounding.
# Different types of bias are Look Ahead Bias, Data Mining Bias, Survival Bias.
#
# This will be a difficult forecast because stock prices are highly fluctuating and are governed by not only past data but various human factors, seasonality and time trend impacts.

# %% [markdown]
# ## Section 2:

# %%
## Importing Libraries 
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
# !pip install pandas-datareader
# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %matplotlib inline
# For reading stock data from yahoo
from pandas_datareader import data

# %% [markdown]
# # Exploratory data analysis

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
comp_list=['AAPL','GOOG','MSFT','AMZN']

# %%
startdate=datetime(enddate.year-1,enddate.month,enddate.day)

# %%
enddate=datetime.now()

# %%
for stock in comp_list:   
   
    globals()[stock] = data.DataReader(stock,'yahoo',startdate,enddate)

# %%
## checking Na values 
AAPL.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
GOOG.isna().sum()
MSFT.isna().sum()
AMZN.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
startdate=datetime(enddate.year-1,enddate.month,enddate.day)

# %%
a=[]
for s in comp_list:
    a.append(data.DataReader(s,'yahoo',startdate,enddate))

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2021-01-20 to 2022-01-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       254 non-null    float64
#  1   Low        254 non-null    float64
#  2   Open       254 non-null    float64
#  3   Close      254 non-null    float64
#  4   Volume     254 non-null    float64
#  5   Adj Close  254 non-null    float64
# dtypes: float64(6)
# memory usage: 13.9 KB

# %%
## statistical summary table of  apple stocks data
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   144.542126  141.620748  143.036418  143.134567  8.977185e+07
# std     16.233678   15.819899   15.950985   16.011635  2.860235e+07
# min    120.400002  116.209999  119.029999  116.360001  4.100000e+07
# 25%    130.982498  128.612503  129.835003  130.247505  6.904782e+07
# 50%    144.415001  141.680000  143.339996  142.930000  8.453615e+07
# 75%    151.362499  148.687496  149.817505  149.942505  1.054095e+08
# max    182.940002  179.119995  182.630005  182.009995  1.954327e+08
#
#         Adj Close
# count  254.000000
# mean   142.794707
# std     16.197160
# min    115.819870
# 25%    129.780857
# 50%    142.656799
# 75%    149.746456
# max    182.009995

# %%
## statistical summary table of google stocks data
GOOG.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   254.000000   254.000000   254.000000   254.000000  2.540000e+02
# mean   2578.939519  2533.582624  2555.558175  2556.956577  1.252252e+06
# std     334.319641   332.480500   335.322318   333.041952  4.841442e+05
# min    1857.280029  1809.000000  1831.459961  1830.790039  5.933000e+05
# 25%    2306.479187  2264.140015  2283.914978  2294.387390  9.338750e+05
# 50%    2665.005005  2630.645020  2651.500000  2658.660034  1.135450e+06
# 75%    2883.400024  2823.952515  2850.277588  2848.855042  1.411050e+06
# max    3037.000000  2997.750000  3020.000000  3014.179932  4.118200e+06
#
#          Adj Close
# count   254.000000
# mean   2556.956577
# std     333.041952
# min    1830.790039
# 25%    2294.387390
# 50%    2658.660034
# 75%    2848.855042
# max    3014.179932

# %%
## statistical summary table of  amazon stocks data
AMZN.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   254.000000   254.000000   254.000000   254.000000  2.540000e+02
# mean   3382.765549  3314.389923  3349.711463  3347.324174  3.359902e+06
# std     157.955993   155.375056   156.115005   156.922759  1.162821e+06
# min    3009.000000  2881.000000  3005.000000  2951.949951  1.680300e+06
# 25%    3280.592468  3220.229980  3250.000000  3247.417542  2.561475e+06
# 50%    3373.845093  3304.505005  3347.390015  3341.725098  3.128850e+06
# 75%    3483.157532  3412.632507  3451.909973  3447.789917  3.824650e+06
# max    3773.080078  3696.790039  3744.000000  3731.409912  9.957100e+06
#
#          Adj Close
# count   254.000000
# mean   3347.324174
# std     156.922759
# min    2951.949951
# 25%    3247.417542
# 50%    3341.725098
# 75%    3447.789917
# max    3731.409912

# %%
## statistical summary table of microsoft stocks data
MSFT.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   282.744722  277.915354  280.320708  280.466968  2.653442e+07
# std     35.733330   35.118263   35.599306   35.425749  8.492240e+06
# min    225.789993  217.289993  217.699997  224.339996  1.390020e+07
# 25%    249.590000  245.774998  247.647499  247.497494  2.023362e+07
# 50%    285.260010  280.399994  282.235001  282.215012  2.477650e+07
# 75%    309.374992  302.517502  304.869995  304.815002  3.063895e+07
# max    349.670013  342.200012  344.619995  343.109985  6.987060e+07
#
#         Adj Close
# count  254.000000
# mean   279.557249
# std     35.940868
# min    222.475159
# 25%    246.368496
# 50%    281.430237
# 75%    304.562813
# max    343.109985

# %%
##Boxplot to find outliers for Apple data
fig2,ax2=plt.subplots(figsize=(20,10),nrows=2,ncols=5)
ax2=ax2.flatten()
start=0
for i,j in AAPL.items():
    sns.boxplot(y=j,ax=ax2[start])
    start+=1

# %% [markdown]
# ### Boxplot:
# **There are few outliers in the data for apple stocks in the columns high, low, open, close and adj close price. There are many outliers in the volume column of data. These outliers can probably be because of the imapct of covid since the data is of past two years.**

# %%
##Boxplot to find outliers for microsoft data
fig1,ax1=plt.subplots(figsize=(20,10),nrows=2,ncols=5)
ax1=ax1.flatten()
start=0
for i,j in MSFT.items():
    sns.boxplot(y=j,ax=ax1[start])
    start+=1

# %%
##Boxplot to find outliers for Amazon data
fig1,ax1=plt.subplots(figsize=(20,10),nrows=2,ncols=5)
ax1=ax1.flatten()
start=0
for i,j in AMZN.items():
    sns.boxplot(y=j,ax=ax1[start])
    start+=1

# %% [markdown]
# ### Boxplot:
# **Similarly there are many outliers in the volume column of microsoft and amazon data probably because of the imapct of covid since the data is of past two years.**

# %%
plt.figure(figsize=(10,10))
AAPL['Adj Close'].plot(legend=True,label='APPLE')
GOOG['Adj Close'].plot(legend=True,label='GOOGLE')
AMZN['Adj Close'].plot(legend=True,label='AMAZON')
MSFT['Adj Close'].plot(legend=True,label='MICROSOFT')

# %% [markdown]
# **The 'adj close' column which depicts the adjusted closure cost for the stocks for the fours companies shows that the adjusted closure cost for apple and google are significantly higher than amazon and microsoft.**

# %%
AAPL['Volume'].plot(legend=True,figsize=(10,4),label='Apple')
GOOG['Volume'].plot(legend=True,figsize=(10,4),label='Google')
AMZN['Volume'].plot(legend=True,figsize=(10,4),label='Amazon')
MSFT['Volume'].plot(legend=True,figsize=(10,4),label='Microsoft')

# %% [markdown]
# **Comparing the volume plots for 4 companies depicts that the volume of stocks for Apple is maximum**

# %%
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    AAPL[column_name]= AAPL['Adj Close'].rolling(ma).mean()
    GOOG[column_name]= GOOG['Adj Close'].rolling(ma).mean()  
    AMZN[column_name]= AMZN['Adj Close'].rolling(ma).mean()
    MSFT[column_name]= MSFT['Adj Close'].rolling(ma).mean()

# %%
AAPL[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4))

# %%
GOOG[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=((10,4)))

# %%
AMZN[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=((10,4)))

# %%
MSFT[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=((10,4)))

# %% [markdown]
# **The adjusted close price moving avaerage for stocks for Apple, google and microsoft has an overall increase in the last month of the year but AMAZON  had a decrease.**

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()
MSFT['Daily Return']= MSFT['Adj Close'].pct_change()
GOOG['Daily Return']= GOOG['Adj Close'].pct_change()
AMZN['Daily Return']= AMZN['Adj Close'].pct_change()

# %%
AAPL['Daily Return'].plot(figsize=(12,4),legend=True,linestyle='--',marker='o')

# %% [markdown]
# **The daily return is fluctuating a lot for apple data**

# %%
plt.figure(figsize=(20,10),constrained_layout=True)
plt.title('See the grap')
sns.distplot(AAPL['Daily Return'],bins=100,color='red')
sns.distplot(GOOG['Daily Return'],bins=100,color='blue')
sns.distplot(AMZN['Daily Return'],bins=100,color='purple')
sns.distplot(MSFT['Daily Return'],bins=100,color='green')
plt.legend(labels=['APPLE', 'GOOGLE','AMAZON','MICROSOFT'],fontsize=20)

# %% [markdown]
# **The histogram shows that daily return is maximum for apple**

# %%
closing_df = data.DataReader(['AAPL','GOOG','MSFT','AMZN'],'yahoo',startdate,enddate)['Adj Close']
closing_df.head()
# Out:
# Symbols           AAPL         GOOG        MSFT         AMZN
# Date
# 2021-01-20  131.221039  1886.900024  222.475143  3263.379883
# 2021-01-21  136.031403  1891.250000  223.099899  3306.989990
# 2021-01-22  138.217911  1901.050049  224.071762  3292.229980
# 2021-01-25  142.044327  1899.400024  227.621994  3294.000000
# 2021-01-26  142.282867  1917.239990  230.398743  3326.129883

# %% [markdown]
# **The closing data for four companies are depicted above**

# %%
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2021-01-20       NaN       NaN       NaN       NaN
# 2021-01-21  0.036658  0.002305  0.002808  0.013363
# 2021-01-22  0.016074  0.005182  0.004356 -0.004463
# 2021-01-25  0.027684 -0.000868  0.015844  0.000538
# 2021-01-26  0.001679  0.009392  0.012199  0.009754

# %% [markdown]
# **The percentage change in closing data for four companies**

# %%
sns.pairplot(tech_rets.dropna())

# %% [markdown]
# **The pair plots show that there is correlation between the percentage change in closing price of the four tech companies. The histograms show that the closing price data for amazon id left skewed and for google it is slightly right skewed**

# %%
tech_rets.dropna().corr()
# Out:
# Symbols      AAPL      GOOG      MSFT      AMZN
# Symbols
# AAPL     1.000000  0.539291  0.659665  0.589221
# GOOG     0.539291  1.000000  0.710815  0.578565
# MSFT     0.659665  0.710815  1.000000  0.558944
# AMZN     0.589221  0.578565  0.558944  1.000000

# %% [markdown]
# **The correlation between the closing price stocks for four companies also shows that correlation exists between the closing price of four companies and also microsoft and google are highly correlated**

# %%
plt.figure(figsize=(20,10))

sns.heatmap(tech_rets.dropna().corr().abs(),annot=True,fmt=".2f",linewidths=0.5,cmap="YlGnBu")

# %% [markdown]
# **The heatmap also shows the same that the percentage change closing price of Microsoft and google are highly correlated**

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
returns_fig = sns.PairGrid(tech_rets.dropna())

# Using map_upper we can specify what the upper triangle will look like.
returns_fig.map_upper(plt.scatter,color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
returns_fig.map_diag(plt.hist,bins=30)

# %% [markdown]
# **Scatter plot showing correlation in the upper half, histograms along the diagonal showing distribution of data that except apple these are not normally distributed.Also density plots are plotted on the lower left**

# %% [markdown]
# ## Section 3
# ## Fitting linear regression model to obtain closing price

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
X_GOOG=GOOG[['High','Low','Open','Adj Close','Volume']]
Y_GOOG=GOOG[['Close']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_GOOG,Y_GOOG,test_size=0.2)
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
from sklearn.metrics import mean_squared_error
linear_MSQ=mean_squared_error(y_test,predicted_values)
np.sqrt(linear_MSQ)
# Out:
# 2.065620565210272e-09

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
X_MSFT=MSFT[['High','Low','Open','Adj Close','Volume']]
Y_MSFT=MSFT[['Close']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_MSFT,Y_MSFT,test_size=0.2)
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
from sklearn.metrics import mean_squared_error
linear_MSQ=mean_squared_error(y_test,predicted_values)
np.sqrt(linear_MSQ)
# Out:
# 0.294946865718594

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
X_AMZN=AMZN[['High','Low','Open','Adj Close','Volume']]
Y_AMZN=AMZN[['Open']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_AMZN,Y_AMZN,test_size=0.2)
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
from sklearn.metrics import mean_squared_error
linear_MSQ=mean_squared_error(y_test,predicted_values)
np.sqrt(linear_MSQ)
# Out:
# 6.0298800726063116e-12

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
X_AAPL=AAPL[['High','Low','Open','Adj Close','Volume']]
Y_AAPL=AAPL[['Close']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_AAPL,Y_AAPL,test_size=0.2)
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
from sklearn.metrics import mean_squared_error
linear_MSQ=mean_squared_error(y_test,predicted_values)
np.sqrt(linear_MSQ)
# Out:
# 0.14156034503513634

# %%
import statsmodels.api as sm

# %%
x=np.array(AAPL[['High','Low','Adj Close','Open']])
y=np.array(AAPL[['Close']])

# %%
model=sm.OLS(y,x)
results=model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.893e+07
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):                        0.00
# Time:                        17:00:02   Log-Likelihood:                         -19.933
# No. Observations:                 254   AIC:                                      47.87
# Df Residuals:                     250   BIC:                                      62.02
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
error=predicted_values-y_test

# %%
plt.plot(predicted_values,error,'.')
plt.xlabel('Fitted Values')
plt.ylabel('Residual Errors')
plt.title('Residual plot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Residual plot')

# %% [markdown]
# # Inference
# **The regression results to obtain closing prices shows that the R2 and adjusted R2 values are 1 which is very unrealistic result. So when we checked the residual plot that is the fitted values versus residual error, it showed that the variance is not constant which violates the assumption of linear regression (homoscedasticity) to predict the values.
# The data is also not noramally distributed which is also an assupmtion for using linear regression model
# So Linear regression model cannot be used for predicting time-series data here**

# %% [markdown]
# # Risk Prediction in stock closing prices using Monte Carlo Simulation

# %%
# Let's start by defining a new DataFrame as a clenaed version of the oriignal tech_rets DataFrame
rets = tech_rets.dropna()

area = np.pi*20

plt.scatter(rets.mean(), rets.std(),alpha = 0.5,s =area)

# Set the x and y limits of the plot (optional, remove this if you don't see anything in your plot)
plt.ylim([0.01,0.025])
plt.xlim([-0.003,0.004])

#Set the plot axis titles
plt.xlabel('Expected returns')
plt.ylabel('Risk')

# Label the scatter plots, for more info on how this is done, chekc out the link below
# http://matplotlib.org/users/annotations_guide.html
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3'))

# %% [markdown]
# # Risk Prediction using Monte Carlo Simulation

# %%
# Set up our time horizon
days = 365

# Now our delta
dt = 1/days

# Now let's grab our mu (drift) from the expected return data we got for AAPL
mu = rets.mean()['GOOG']

# Now let's grab the volatility of the stock from the std() of the average return
sigma = rets.std()['GOOG']


def stock_monte_carlo(start_price,days,mu,sigma):
    ''' This function takes in starting stock price, days of simulation,mu,sigma, and returns simulated price array'''
    
    # Define a price array
    price = np.zeros(days)
    price[0] = start_price
    # Schok and Drift
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    # Run price array for number of days
    for x in range(1,days):
        
        # Calculate Schock
        shock[x] = np.random.normal(loc=mu * dt, scale=sigma * np.sqrt(dt))
        # Calculate Drift
        drift[x] = mu * dt
        # Calculate Price
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price


# Get start price from GOOG.head()
start_price = 569.85

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for Google')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis for Google')
